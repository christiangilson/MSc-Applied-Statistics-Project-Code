# %%
import pandas as pd
import numpy as np
import os

pd.set_option('max_columns', None)
pd.set_option('max_rows', 2500)

# %% [markdown]
# # **Paired xT**
#
# So here we want to do a join on itself to produce a summary statistic for actions that move the ball to another player on the same team.
#
# The summary statistic will be the aggregate sum of xT between pairs of players, and we'll call this *paired xT*.
#
# ## **Loading Opta Bayesian xT Data**

# %%
# %%time

df_opta_xT = pd.read_csv('/Users/christian/Desktop/University/Birkbeck MSc Applied Statistics/Project/Data/Analysis Ready/Opta Bayesian xT/Bayesian_Opta_xT.csv')

# converting the timestamp string to a datetime
df_opta_xT['timeStamp'] = pd.to_datetime(df_opta_xT.timeStamp, format='%Y-%m-%d %H:%M:%S.%f')
df_opta_xT['kickOffDateTime'] = pd.to_datetime(df_opta_xT.kickOffDateTime, format='%Y-%m-%d %H:%M:%S.%f')

print (f'{len(df_opta_xT)} rows loaded.\n')

df_opta_xT.head()
# Out:
# 3126182 rows loaded.
#
# CPU times: user 14 s, sys: 1.75 s, total: 15.7 s
# Wall time: 16.1 s
#               competition   season  seasonIndex  gameMonthIndex  matchId  \
# 0  English Premier League  2017/18            1           24212   918893
# 1  English Premier League  2017/18            1           24212   918893
# 2  English Premier League  2017/18            1           24212   918893
# 3  English Premier League  2017/18            1           24212   918893
# 4  English Premier League  2017/18            1           24212   918893
#
#    playerId           playerName    position     detailedPosition  \
# 0     59966  Alexandre Lacazette     Forward              Striker
# 1    156074          Rob Holding    Defender             FullBack
# 2     37605           Mesut Özil     Forward  AttackingMidfielder
# 3    153256       Mohamed Elneny  Midfielder    CentralMidfielder
# 4     98745      Héctor Bellerín  Midfielder      RightMidfielder
#
#    playerTeamId  minsPlayed  subIn  subOut  replacedReplacingPlayerId booking  \
# 0             3          95    NaN     NaN                        NaN     NaN
# 1             3          67    NaN     1.0                        NaN     NaN
# 2             3          95    NaN     NaN                        NaN     NaN
# 3             3          66    NaN     1.0                        NaN     NaN
# 4             3          95    NaN     NaN                        NaN     NaN
#
#   eventType eventSubType  eventTypeId    x1    y1    x2    y2 gameTime  \
# 0    attack         Pass            1  50.0  50.7  28.8  30.1      0:1
# 1    attack         Pass            1  29.7  26.7  52.3  21.5      0:2
# 2    attack         Pass            1  52.8  21.3  44.3  20.7      0:5
# 3    attack         Pass            1  44.0  19.6  50.3   4.2      0:7
# 4    attack         Pass            1  51.0   4.2  70.5   5.0      0:9
#
#                 timeStamp  periodId homeTeamName  homeTeamId    awayTeamName  \
# 0 2017-08-11 19:46:04.968         1      Arsenal           3  Leicester City
# 1 2017-08-11 19:46:05.554         1      Arsenal           3  Leicester City
# 2 2017-08-11 19:46:08.554         1      Arsenal           3  Leicester City
# 3 2017-08-11 19:46:10.554         1      Arsenal           3  Leicester City
# 4 2017-08-11 19:46:13.519         1      Arsenal           3  Leicester City
#
#    awayTeamId     kickOffDateTime  minute  second    x1_m    y1_m    x2_m  \
# 0          13 2017-08-11 19:45:00       0       1  52.500  34.476  30.240
# 1          13 2017-08-11 19:45:00       0       2  31.185  18.156  54.915
# 2          13 2017-08-11 19:45:00       0       5  55.440  14.484  46.515
# 3          13 2017-08-11 19:45:00       0       7  46.200  13.328  52.815
# 4          13 2017-08-11 19:45:00       0       9  53.550   2.856  74.025
#
#      y2_m        xT
# 0  20.468 -0.003278
# 1  14.620  0.003008
# 2  14.076 -0.001186
# 3   2.856 -0.000542
# 4   3.400  0.005850

# %% [markdown]
# ## **Opta Pass Events**

# %%
# pass events (inc. crosses)
opta_successful_pass_events = ['2nd Assist','Assist','Chance Created','Cross','Pass']
opta_failed_pass_events = ['Failed Pass','Offside Pass']

# %% [markdown]
# ## **Producing Pairs**

# %%
# %%time

# really we just want to filter on all attack events, and then look for when a (successful) pass is followed up by a subsequent attack event by the same team.
df_attack = df_opta_xT.loc[df_opta_xT['eventType'] == 'attack'].sort_values(['seasonIndex','competition','matchId','timeStamp'], ascending=[True, True, True, True]).reset_index(drop=True)

# initialising two new columns: 1) receiver player and 2) receiver player id
df_attack['receiverPlayerName'] = None
df_attack['receiverPlayerId'] = None

# logic: different players, same team, same match, same half, first event is a successful pass-like action, and the follow on event is still an attack (which is by the same team)
df_attack.loc[((df_attack['playerId'] != df_attack['playerId'].shift(-1)) & (df_attack['playerTeamId'] == df_attack['playerTeamId'].shift(-1)) & (df_attack['matchId'] == df_attack['matchId'].shift(-1)) & (df_attack['periodId'] == df_attack['periodId'].shift(-1)) & (df_attack['eventSubType'].isin(opta_successful_pass_events)) & (df_attack['eventType'] == 'attack')), 'receiverPlayerName'] = df_attack['playerName'].shift(-1)
df_attack.loc[((df_attack['playerId'] != df_attack['playerId'].shift(-1)) & (df_attack['playerTeamId'] == df_attack['playerTeamId'].shift(-1)) & (df_attack['matchId'] == df_attack['matchId'].shift(-1)) & (df_attack['periodId'] == df_attack['periodId'].shift(-1)) & (df_attack['eventSubType'].isin(opta_successful_pass_events)) & (df_attack['eventType'] == 'attack')), 'receiverPlayerId'] = df_attack['playerId'].shift(-1)

# getting rid of Nones where the pass was not successfully mapped
df_attack = df_attack.loc[pd.isna(df_attack['receiverPlayerName']) == False].reset_index(drop=True).copy()
df_attack['receiverPlayerId'] = df_attack.receiverPlayerId.astype(int)

# and now creating pair objects to group over (this is the bit that takes a little bit of time)
df_attack['pairName'] = df_attack.apply(lambda x: ('-').join(sorted([x.receiverPlayerName] + [x.playerName])), axis=1)
df_attack['pairIds'] = df_attack.apply(lambda x: sorted([x.receiverPlayerId] + [x.playerId]), axis=1)
df_attack['playerA'] = df_attack.pairIds.apply(lambda x: min(x))
df_attack['playerB'] = df_attack.pairIds.apply(lambda x: max(x))
# Out:
# CPU times: user 1min 10s, sys: 7.43 s, total: 1min 18s
# Wall time: 1min 21s

# %% [markdown]
# ## **Producing Pair Statistics**

# %%
df_epl = df_attack.loc[df_attack['competition'] == 'English Premier League'].reset_index(drop=True)
df_cl = df_attack.loc[df_attack['competition'] == 'Champions League'].reset_index(drop=True)

# %% [markdown]
# ### Directional Pairs

# %%
"""
df_pairs = df_epl.groupby(['competition','season','playerName','playerId','receiverPlayerName','receiverPlayerId'])\
            .agg({'xT':np.sum,'x1':'count'})\
            .reset_index()\
            .rename(columns={'x1':'numActions'})

df_pairs.loc[df_pairs['numActions'] > 50].sort_values(['xT'], ascending=[False]).head()
"""
# Out:
# "\ndf_pairs = df_epl.groupby(['competition','season','playerName','playerId','receiverPlayerName','receiverPlayerId'])            .agg({'xT':np.sum,'x1':'count'})            .reset_index()            .rename(columns={'x1':'numActions'})\n\ndf_pairs.loc[df_pairs['numActions'] > 50].sort_values(['xT'], ascending=[False]).head()\n"

# %% [markdown]
# ### Directionless pairs: pure chemistry between pairs of players
#
# #### 1. Premier League

# %%
df_epl_pairs = df_epl.groupby(['competition','playerTeamId','season','pairName'])\
            .agg({'xT':np.sum,'x1':'count'})\
            .reset_index()\
            .rename(columns={'x1':'numActions'})

# applying season by season rank
df_epl_pairs['seasonRank'] = df_epl_pairs.sort_values(['season','xT'], ascending=[True, False]).groupby('season').cumcount() + 1

# sorting by season
df_epl_pairs.loc[(df_epl_pairs['seasonRank'] <= 20) & (df_epl_pairs['season'].isin(['2020/21']))].sort_values(['season', 'seasonRank'], ascending=[True, True]).reset_index(drop=True)
# Out:
#                competition  playerTeamId   season  \
# 0   English Premier League            14  2020/21
# 1   English Premier League            14  2020/21
# 2   English Premier League            20  2020/21
# 3   English Premier League            90  2020/21
# 4   English Premier League            31  2020/21
# 5   English Premier League             6  2020/21
# 6   English Premier League            14  2020/21
# 7   English Premier League            21  2020/21
# 8   English Premier League            90  2020/21
# 9   English Premier League            90  2020/21
# 10  English Premier League            36  2020/21
# 11  English Premier League             2  2020/21
# 12  English Premier League            14  2020/21
# 13  English Premier League             2  2020/21
# 14  English Premier League             7  2020/21
# 15  English Premier League            14  2020/21
# 16  English Premier League             7  2020/21
# 17  English Premier League             1  2020/21
# 18  English Premier League             1  2020/21
# 19  English Premier League            14  2020/21
#
#                                   pairName        xT  numActions  seasonRank
# 0              Andrew Robertson-Sadio Mané  2.433447         567           1
# 1                 Mohamed Salah-Sadio Mané  2.349852         125           2
# 2     James Ward-Prowse-Jannik Vestergaard  2.235552         421           3
# 3          Ashley Westwood-James Tarkowski  2.162142         368           4
# 4        Andros Townsend-Christian Benteke  2.107945          76           5
# 5                 Harry Kane-Son Heung-Min  1.950966         182           6
# 6         Andrew Robertson-Roberto Firmino  1.950019         357           7
# 7             Aaron Cresswell-Tomas Soucek  1.817882         217           8
# 8            Dwight McNeil-James Tarkowski  1.809613          84           9
# 9               Ashley Westwood-Chris Wood  1.798031         171          10
# 10                  Lewis Dunk-Pascal Groß  1.704488         234          11
# 11                    Luke Ayling-Raphinha  1.682991         311          12
# 12    Mohamed Salah-Trent Alexander-Arnold  1.647872         632          13
# 13                Patrick Bamford-Raphinha  1.558325          81          14
# 14             Jack Grealish-Ollie Watkins  1.549871         211          15
# 15  Roberto Firmino-Trent Alexander-Arnold  1.532484         248          16
# 16              Matt Targett-Ollie Watkins  1.513799         243          17
# 17         Bruno Fernandes-Marcus Rashford  1.493446         392          18
# 18                 Harry Maguire-Luke Shaw  1.415627         635          19
# 19       Sadio Mané-Trent Alexander-Arnold  1.352147         156          20

# %% [markdown]
# #### 2. Champions League

# %%
df_cl_pairs = df_cl.groupby(['competition','season','pairName'])\
            .agg({'xT':np.sum,'x1':'count'})\
            .reset_index()\
            .rename(columns={'x1':'numActions'})

# applying season by season rank
df_cl_pairs['seasonRank'] = df_cl_pairs.sort_values(['season','xT'], ascending=[True, False]).groupby('season').cumcount() + 1

# sorting by season
df_cl_pairs.loc[df_cl_pairs['seasonRank'] <= 5].sort_values(['season', 'seasonRank'], ascending=[True, True]).reset_index(drop=True)
# Out:
#         competition   season                           pairName        xT  \
# 0  Champions League  2017/18  Joshua Kimmich-Robert Lewandowski  1.108728
# 1  Champions League  2017/18      Mohamed Salah-Roberto Firmino  0.869003
# 2  Champions League  2017/18          Cristiano Ronaldo-Marcelo  0.783347
# 3  Champions League  2017/18      Anthony Martial-Romelu Lukaku  0.730775
# 4  Champions League  2017/18        Clément Lenglet-Éver Banega  0.729998
# 5  Champions League  2018/19           Dusan Tadic-Hakim Ziyech  1.292699
# 6  Champions League  2018/19         Harry Kane-Kieran Trippier  1.195510
# 7  Champions League  2018/19              Marcelo-Memphis Depay  1.034083
# 8  Champions League  2018/19      Hakim Ziyech-Matthijs de Ligt  0.949098
# 9  Champions League  2018/19            David Neres-Dusan Tadic  0.894506
#
#    numActions  seasonRank
# 0          46           1
# 1          82           2
# 2         109           3
# 3          19           4
# 4         138           5
# 5         128           1
# 6          26           2
# 7          28           3
# 8          64           4
# 9         106           5

# %% [markdown]
# ## **Interesting Metric! Team Pair Concentration**
#
# > How much xT is concentrated between pairs?
#
# > Do teams share the load or do they create threat between just a few combinations of players?

# %%
df_epl_denom = df_epl_pairs\
                .groupby(['competition','season','playerTeamId'])\
                .agg({'xT':np.sum,'numActions':np.sum})\
                .reset_index()\
                .rename(columns={'xT':'xT_Team','numActions':'numActions_Team'})

df_epl_conc = df_epl_pairs.merge(df_epl_denom, how='inner', on=['competition','season','playerTeamId'])

df_epl_conc['xT_Prop'] = df_epl_conc.xT / df_epl_conc.xT_Team
df_epl_conc['numActions_Prop'] = df_epl_conc.numActions / df_epl_conc.numActions_Team

df_epl_conc['xT_Prop_Rank'] = df_epl_conc.sort_values(['season','xT_Prop'], ascending=[True,False]).groupby('season').cumcount() + 1

# %%
df_epl_conc.loc[(df_epl_conc['xT_Prop_Rank'] <= 5) & (df_epl_conc['season'].isin(['2020/21','2019/20','2018/19','2017/18']))].sort_values(['season','xT_Prop_Rank'], ascending=[True, True]).reset_index(drop=True)
# Out:
#                competition  playerTeamId   season  \
# 0   English Premier League            36  2017/18
# 1   English Premier League            36  2017/18
# 2   English Premier League            38  2017/18
# 3   English Premier League             6  2017/18
# 4   English Premier League            31  2017/18
# 5   English Premier League            54  2018/19
# 6   English Premier League            13  2018/19
# 7   English Premier League            13  2018/19
# 8   English Premier League             4  2018/19
# 9   English Premier League            54  2018/19
# 10  English Premier League            90  2019/20
# 11  English Premier League            39  2019/20
# 12  English Premier League            39  2019/20
# 13  English Premier League            36  2019/20
# 14  English Premier League            11  2019/20
# 15  English Premier League            20  2020/21
# 16  English Premier League             6  2020/21
# 17  English Premier League            31  2020/21
# 18  English Premier League            14  2020/21
# 19  English Premier League            90  2020/21
#
#                                  pairName        xT  numActions  seasonRank  \
# 0                 Pascal Groß-Shane Duffy  2.426302          93           2
# 1                  Lewis Dunk-Pascal Groß  2.055232          93           3
# 2        Florent Hadergjonaj-Steve Mounie  1.286060          89          33
# 3            Christian Eriksen-Harry Kane  2.495666         197           1
# 4       Andros Townsend-Christian Benteke  2.021990         103           4
# 5           Aleksandar Mitrovic-Joe Bryan  2.539838         149           2
# 6            Harry Maguire-James Maddison  2.655904         238           1
# 7            James Maddison-Wilfred Ndidi  2.516397         352           3
# 8             Matt Ritchie-Salomón Rondón  1.856748         185          10
# 9   Aleksandar Mitrovic-Jean Michael Seri  1.943413         218           8
# 10          Dwight McNeil-James Tarkowski  2.750098          99           1
# 11             João Moutinho-Raúl Jiménez  2.039790         182           5
# 12              Adama Traoré-Raúl Jiménez  1.817291         184          11
# 13                 Lewis Dunk-Pascal Groß  2.118031          90           4
# 14                Lucas Digne-Richarlison  2.303053         222           2
# 15   James Ward-Prowse-Jannik Vestergaard  2.235552         421           3
# 16               Harry Kane-Son Heung-Min  1.950966         182           6
# 17      Andros Townsend-Christian Benteke  2.107945          76           5
# 18            Andrew Robertson-Sadio Mané  2.433447         567           1
# 19        Ashley Westwood-James Tarkowski  2.162142         368           4
#
#       xT_Team  numActions_Team   xT_Prop  numActions_Prop  xT_Prop_Rank
# 0   22.938978            11284  0.105772         0.008242             1
# 1   22.938978            11284  0.089596         0.008242             2
# 2   16.359699            10196  0.078611         0.008729             3
# 3   33.205896            18867  0.075157         0.010442             4
# 4   27.983970            11473  0.072255         0.008978             5
# 5   27.214286            14710  0.093327         0.010129             1
# 6   28.744849            14297  0.092396         0.016647             2
# 7   28.744849            14297  0.087543         0.024621             3
# 8   24.515535            10454  0.075738         0.017697             4
# 9   27.214286            14710  0.071412         0.014820             5
# 10  27.095751             9733  0.101496         0.010172             1
# 11  22.477018            13939  0.090750         0.013057             2
# 12  22.477018            13939  0.080851         0.013200             3
# 13  26.565062            15531  0.079730         0.005795             4
# 14  31.208832            13114  0.073795         0.016928             5
# 15  19.664745            14623  0.113683         0.028790             1
# 16  20.490116            16197  0.095215         0.011237             2
# 17  24.194371            11385  0.087125         0.006675             3
# 18  31.535501            21561  0.077165         0.026297             4
# 19  28.697219            10549  0.075343         0.034885             5

# %% [markdown]
# ### **Kane-Son**
#
# > Deeply impacted by loss of Christian Eriksen

# %%
df_epl_conc.loc[(df_epl_conc['season'].isin(['2020/21','2019/20','2018/19','2017/18']) & (   (df_epl_conc.pairName.str.contains('Harry Kane-Son Heung-Min')) | df_epl_conc.pairName.str.contains('Christian Eriksen-Harry Kane'))  )].sort_values(['season','xT_Prop_Rank'], ascending=[True, True]).reset_index(drop=True)
# Out:
#               competition  playerTeamId   season  \
# 0  English Premier League             6  2017/18
# 1  English Premier League             6  2017/18
# 2  English Premier League             6  2018/19
# 3  English Premier League             6  2018/19
# 4  English Premier League             6  2019/20
# 5  English Premier League             6  2019/20
# 6  English Premier League             6  2020/21
#
#                        pairName        xT  numActions  seasonRank    xT_Team  \
# 0  Christian Eriksen-Harry Kane  2.495666         197           1  32.870777
# 1      Harry Kane-Son Heung-Min  0.332124          81         509  32.870777
# 2  Christian Eriksen-Harry Kane  1.248848         120          49  27.792189
# 3      Harry Kane-Son Heung-Min  0.347044          83         496  27.792189
# 4      Harry Kane-Son Heung-Min  1.054963          98          45  19.434139
# 5  Christian Eriksen-Harry Kane  0.488594          60         276  19.434139
# 6      Harry Kane-Son Heung-Min  1.950966         182           6  20.014417
#
#    numActions_Team   xT_Prop  numActions_Prop  xT_Prop_Rank
# 0            18802  0.075924         0.010478             4
# 1            18802  0.010104         0.004308           645
# 2            18351  0.044935         0.006539            44
# 3            18351  0.012487         0.004523           479
# 4            15651  0.054284         0.006262            18
# 5            15651  0.025141         0.003834           150
# 6            16149  0.097478         0.011270             2

# %% [markdown]
# ## Way of showing this off in report:
#
# 1. Provide tables per season (maybe top 5 pairs per season)
#     * Pascal Gross pivotal in staying up for Brighton in the 2017/18 season: http://wearebrighton.com/albionfeatures/the-wearebrighton-com-2017-18-end-of-season-awards/
#     * Raul Jiminez key in the 2019/20 season, big injury, and Adama Traore having a relatively poor season as a result the year after https://theathletic.com/2445216/2021/03/15/adama-traore-wolves/
#     * Dwight Mcneil and James Tarkowski worthy of England call  up: https://www.skysports.com/football/news/11708/12028395/nick-pope-james-tarkowski-and-dwight-mcneil-worthy-of-england-call-says-sean-dyche
# 2. Provide specific changes at Spurs: show grouped bar charts (rather than stacked), one bar per player, specifically for Kane, where one bar will be Eriksen, one will be Son, and pick a couple of others. And show that for the four years. Do the top 4 players per season to show that changing through the seasons.
#     * Provide stategic viewpoint from Spurs' perspective
#     * Provide strategic viewpoint from Spurs' opponents perspective
# 3. **Interesting thing: are the links between midfield and attack, between defence and midfield, or between defence and attack?**
# 4. Think about the care that must go into a transfer... If you sell one player, perhaps you strip away the output of the other. Can see this in the injury to Raul Jiminez. Wolves largely unchanged. Before and after the injury?
# 5. Final thing to think about: maybe normalise per action? Normalising not necessarily a big deal here, because you're actually normalising by a team's total xT output, and looking at a concentration.
