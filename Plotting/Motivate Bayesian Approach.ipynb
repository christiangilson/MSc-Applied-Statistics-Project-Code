# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

pd.set_option('display.max_rows', 2500)
pd.set_option('display.max_columns', 100)

# %%
df_shots = pd.read_csv('/Users/christian/Desktop/University/Birkbeck MSc Applied Statistics/Project/Data/Analysis Ready/Opta Engineered Shots/Engineered Shots.csv')

# converting the timestamp string to a datetime for shots
df_shots['timeStamp'] = pd.to_datetime(df_shots.timeStamp, format='%Y-%m-%d %H:%M:%S.%f')
df_shots['kickOffDateTime'] = pd.to_datetime(df_shots.kickOffDateTime, format='%Y-%m-%d %H:%M:%S.%f')

# %%
df_shots.head()
# Out:
#               competition   season  seasonIndex  gameMonthIndex  matchId  \
# 0  English Premier League  2017/18            1           24212   918893
# 1  English Premier League  2017/18            1           24212   918893
# 2  English Premier League  2017/18            1           24212   918893
# 3  English Premier League  2017/18            1           24212   918893
# 4  English Premier League  2017/18            1           24212   918893
#
#    playerId               playerName    position detailedPosition  \
# 0     59966      Alexandre Lacazette     Forward          Striker
# 1    103025             Riyad Mahrez  Midfielder  RightMidfielder
# 2     78412           Shinji Okazaki     Forward   SencondStriker
# 3     81880  Alex Oxlade-Chamberlain  Midfielder   LeftMidfielder
# 4     81880  Alex Oxlade-Chamberlain  Midfielder   LeftMidfielder
#
#    playerTeamId  minsPlayed  subIn  subOut  replacedReplacingPlayerId booking  \
# 0             3          95    NaN     NaN                        NaN     NaN
# 1            13          95    NaN     NaN                        NaN     NaN
# 2            13          71    NaN     1.0                        NaN     NaN
# 3             3          95    NaN     NaN                        NaN     NaN
# 4             3          95    NaN     NaN                        NaN     NaN
#
#    eventId eventType eventSubType  eventTypeId    x1    y1     x2    y2  \
# 0       52      shot         Goal           16  88.5  52.6  100.0  54.3
# 1       69      shot         Miss           13  85.3  46.7  100.0  58.0
# 2       98      shot         Goal           16  97.6  46.6  100.0  50.1
# 3      146      shot         Miss           13  80.7  72.0  100.0  54.8
# 4      267      shot   Shot Saved           15  78.6  64.3   96.9  51.8
#
#   gameTime               timeStamp  periodId homeTeamName  homeTeamId  \
# 0     1:34 2017-08-11 19:47:37.688         1      Arsenal           3
# 1      3:0 2017-08-11 19:49:04.201         1      Arsenal           3
# 2     4:14 2017-08-11 19:50:17.554         1      Arsenal           3
# 3      7:4 2017-08-11 19:53:08.344         1      Arsenal           3
# 4    13:35 2017-08-11 19:59:39.270         1      Arsenal           3
#
#      awayTeamName  awayTeamId     kickOffDateTime  minute  second     x1_m  \
# 0  Leicester City          13 2017-08-11 19:45:00       1      34   92.925
# 1  Leicester City          13 2017-08-11 19:45:00       3       0   89.565
# 2  Leicester City          13 2017-08-11 19:45:00       4      14  102.480
# 3  Leicester City          13 2017-08-11 19:45:00       7       4   84.735
# 4  Leicester City          13 2017-08-11 19:45:00      13      35   82.530
#
#      y1_m     x2_m    y2_m  possessionTeamId  possessionSequenceIndex  \
# 0  35.768  105.000  36.924                 3                       11
# 1  31.756  105.000  39.440                13                       18
# 2  31.688  105.000  34.068                13                       24
# 3  48.960  105.000  37.264                 3                       33
# 4  43.724  101.745  35.224                 3                       59
#
#        possessionStartTime  possessionTimeSec  playerPossessionTimeSec  \
# 0  2017-08-11 19:46:53.838             43.850                    1.313
# 1  2017-08-11 19:49:04.201              0.000                    0.000
# 2  2017-08-11 19:50:10.314              7.240                    0.000
# 3  2017-08-11 19:52:53.784             14.560                    4.487
# 4  2017-08-11 19:59:36.554              2.716                    0.143
#
#    goalDelta  numReds  goalScoredFlag   xT  x_dist_goal  x_dist_goal_2  \
# 0          1        0               1  0.0       12.075     145.805625
# 1         -1        0               0  0.0       15.435     238.239225
# 2          0        0               1  0.0        2.520       6.350400
# 3          0        0               0  0.0       20.265     410.670225
# 4          0        0               0  0.0       22.470     504.900900
#
#      c1_m      c1_m_2   vec_x   vec_y          D     Dsquared        Dcubed  \
# 0   1.768    3.125824  12.075  32.232  34.419579  1184.707449  40777.132157
# 1   2.244    5.035536  15.435  31.756  35.308395  1246.682761  44018.367427
# 2   2.312    5.345344   2.520  31.688  31.788044  1010.479744  32121.174606
# 3  14.960  223.801600  20.265  19.040  27.806327   773.191825  21499.624772
# 4   9.724   94.556176  22.470  24.276  33.079073  1094.225076  36195.951258
#
#           a  aShooting  pressureCountOnShot  penaltyFlag
# 0  0.358444   0.577882                    0            0
# 1  0.452425   0.456820                    0            0
# 2  0.079358   1.662688                    0            0
# 3  0.816555   0.234451                    0            0
# 4  0.746783   0.273615                    0            0

# %%
df_shots = df_shots.sort_values('timeStamp').reset_index(drop=True)
df_shots['RN'] = df_shots.index + 1
df_shots['GN'] = np.floor(df_shots['RN'] / 250).astype(int)

# %%
df_agg = df_shots.groupby('GN').agg({'D':np.mean, 'c1_m':np.mean, 'x_dist_goal':np.mean}).reset_index()
df_agg.to_csv('grouped_shot_distances.csv', index=None)

# %%
len(df_shots)
# Out:
# 43813
